# %%
import os
import sys

# %%
print(sys.path)
# Out:
# ['c:\\Users\\renes\\repos\\PLUS_softwaredev_2025_-madeByRene-', 'C:\\Program Files\\WindowsApps\\PythonSoftwareFoundation.Python.3.11_3.11.2544.0_x64__qbz5n2kfra8p0\\python311.zip', 'C:\\Program Files\\WindowsApps\\PythonSoftwareFoundation.Python.3.11_3.11.2544.0_x64__qbz5n2kfra8p0\\DLLs', 'C:\\Program Files\\WindowsApps\\PythonSoftwareFoundation.Python.3.11_3.11.2544.0_x64__qbz5n2kfra8p0\\Lib', 'C:\\Program Files\\WindowsApps\\PythonSoftwareFoundation.Python.3.11_3.11.2544.0_x64__qbz5n2kfra8p0', '', 'C:\\Users\\renes\\AppData\\Local\\Packages\\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\\LocalCache\\local-packages\\Python311\\site-packages', 'C:\\Users\\renes\\AppData\\Local\\Packages\\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\\LocalCache\\local-packages\\Python311\\site-packages\\win32', 'C:\\Users\\renes\\AppData\\Local\\Packages\\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\\LocalCache\\local-packages\\Python311\\site-packages\\win32\\lib', 'C:\\Users\\renes
# ...

# %%
help("modules")
# Out:
# Please wait a moment while I gather a list of all available modules...
#
# Python version: 3.11.9 (tags/v3.11.9:de54cf5, Apr  2 2024, 10:12:12) [MSC v.1938 64 bit (AMD64)]
# GEOS version: 3.11.3-CAPI-1.17.3
# Numpy version: 1.26.0
# ...
# Decompressing WhiteboxTools_win_amd64.zip ...
# WhiteboxTools package directory: C:\Users\renes\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\whitebox
# ...
# FireHR              colour              marshmallow         spacy
# IPython             comm                math                spacy_legacy
# PIL                 commctrl            matplotlib          spacy_loggers
# __future__          compileall          matplotlib_inline   sqlite3
# __hello__           concurrent          mdurl               sre_compile
# __phello__          confection          mimetypes           sre_constants
# _abc                configparser        mistune             sre_parse
# ...

# %%
daysOfTheWeek = 7
def sayHello(recipient:str) -> str:
    print("Hello, world! Hello {0}".format(recipient))
    return recipient

sayHello("Gustav Gans")
# Out:
# Hello, world! Hello Gustav Gans
# 'Gustav Gans'
