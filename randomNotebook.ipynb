# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
arr = np.random.random(20)

# %%
plt.hist(arr)
# Out:
# (array([5., 2., 0., 1., 3., 2., 1., 2., 1., 3.]),
#  array([0.01825626, 0.11024531, 0.20223435, 0.2942234 , 0.38621245,
#         0.4782015 , 0.57019055, 0.6621796 , 0.75416864, 0.84615769,
#         0.93814674]),
#  <BarContainer object of 10 artists>)
